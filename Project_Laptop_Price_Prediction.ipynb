# %% [markdown]
# <a href="https://colab.research.google.com/github/annamarydona/project/blob/main/Project_Laptop_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PREDICTING,ANALYSING & VISUALIZING THE DATASET OF LAPTOPS**

# %% [markdown]
# i'm prediting laptop price using different regression models

# %%
#importing essential python packages
import numpy as np                    #these packages are commonly konwn as EDA tools (Exploratory data analysis)
import pandas as pd                   # numpy is for mathematical (matrix and foreier) ,pandas is for data manupulation ,data cleaning ,data handiling
import matplotlib.pyplot as plt
import seaborn as sb                  #seaborn and matplotlib is for data visulization

# %%
#reading the file
a=pd.read_csv("/content/laptop_data.csv")
a
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
a.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
a.tail()
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# ...

# %%
#rows and columns
a.shape
# Out:
# (1303, 12)

# %%
#dimension
a.ndim
# Out:
# 2

# %%
#size of the data ( rows*columns )
a.size
# Out:
# 15636

# %%
# datatypes of the columns
a.dtypes
# Out:
# Unnamed: 0            int64
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price               float64
# dtype: object

# %%
#columns names
a.columns
# Out:
# Index(['Unnamed: 0', 'Company', 'TypeName', 'Inches', 'ScreenResolution',
#        'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %% [markdown]
# **MISSING VALUES**

# %%
a.isna().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
#column drop
#the data is modified in place, which means it will return nothing and the dataframe is now updated
a.drop(['Unnamed: 0'],axis=1,inplace=True)
a
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
#decription of the data
a.describe()
# Out:
#             Inches          Price
# count  1303.000000    1303.000000
# mean     15.017191   59870.042910
# std       1.426304   37243.201786
# min      10.100000    9270.720000
# 25%      14.000000   31914.720000
# 50%      15.600000   52054.560000
# 75%      15.600000   79274.246400
# max      18.400000  324954.720000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_7841095608433328229 = autoviz.get_df('df_7841095608433328229')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# ...

# %% [markdown]
# **CORELATION**

# %%
#dependency of numerical relationship
#positive correlation - relationship between two variables that change together
#inverse correlation (Ncorr)-relationship between two variables which change in opposing directions.
a.corr()
# Out:
# <ipython-input-13-8cd060a3ed1c>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()
#           Inches     Price
# Inches  1.000000  0.068197
# Price   0.068197  1.000000

# %% [markdown]
# **HEATMAP OF CORRELATION ABOVE**

# %%
# heatmap two-dimensional graphical representation of data
sb.heatmap(a.corr())
# Out:
# <ipython-input-14-327b1bd0a7cd>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(a.corr())
# <Axes: >

# %% [markdown]
# **STRING REPLACE**

# %%
#string replace
a['Ram'] = a['Ram'].str.replace('GB','')
a['Weight'] = a['Weight'].str.replace('kg','')
a.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %% [markdown]
# **CHANGING DATATYPE**

# %%
#data type change
a['Ram'] = a['Ram'].astype('int32')
a['Weight'] =a['Weight'].astype('float32')
a.dtypes
# Out:
# Company              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                   int32
# Memory               object
# Gpu                  object
# OpSys                object
# Weight              float32
# Price               float64
# dtype: object

# %% [markdown]
# **PRICE COUNT**

# %%
a['Price'].value_counts()
# Out:
# 79866.72     14
# 58554.72     14
# 95850.72     14
# 47898.72     11
# 63882.72     11
#              ..
# 111355.20     1
# 16197.12      1
# 40439.52      1
# 98994.24      1
# 143802.72     1
# Name: Price, Length: 791, dtype: int64

# %%
#displot - used to plot the univarient
sb.displot(a['Price'])
plt.title('Price Count',size=18)
# Out:
# Text(0.5, 1.0, 'Price Count')

# %%
a['Company'].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
#barplot - represent data in the form of rectangular bars
a['Company'].value_counts().plot(kind='bar')
plt.title('companys X Count',size=18)
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sb.barplot(x=a['Company'],y=a['Price'])
plt.title('Companys X Price ',size=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
a['TypeName'].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
a['TypeName'].value_counts().plot(kind='bar')
plt.title('Types X Count',size=18)
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sb.barplot(x=a['TypeName'],y=a['Price'])
plt.title('TypeName X Price ',size=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
a['Inches'].value_counts()
# Out:
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: Inches, dtype: int64

# %%
sb.displot(a['Inches'])
plt.title('Inches Count',size=18)
# Out:
# Text(0.5, 1.0, 'Inches Count')

# %%
a['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
#lambda is functional prgmming Method (reduce the length of the code) #map #filter
#in this code touchscreen is present in the data it returns 1 otherwise 0 and saved in touchsreen column
a['Touchscreen'] = a['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)
a.sample(5)
# Out:
#     Company            TypeName  Inches                  ScreenResolution  \
# 964      HP            Notebook    15.6                          1366x768
# 795  Lenovo  2 in 1 Convertible    14.0   IPS Panel Touchscreen 2560x1440
# 456    Dell            Notebook    17.3       IPS Panel Full HD 1920x1080
# 540    Dell           Ultrabook    13.3  Quad HD+ / Touchscreen 3200x1800
# 610  Lenovo            Notebook    15.6   IPS Panel 4K Ultra HD 3840x2160
#
#                                Cpu  Ram     Memory                      Gpu  \
# 964    Intel Core i5 7200U 2.50GHz    8    1TB HDD     Nvidia GeForce 930MX
# 795     Intel Core i5 7200U 2.5GHz    8  256GB SSD    Intel HD Graphics 620
# 456    Intel Core i7 7700HQ 2.7GHz    8    1TB HDD  Nvidia GeForce GTX 1060
# 540     Intel Core i7 8550U 1.8GHz    8  256GB SSD   Intel UHD Graphics 620
# 610  Intel Xeon E3-1535M v6 3.1GHz   32    1TB SSD     Nvidia Quadro M2200M
#
#           OpSys  Weight      Price  Touchscreen
# ...

# %%
# Counts of Touch and non Touch
a['Touchscreen'].value_counts()
# Out:
# 0    1111
# 1     192
# Name: Touchscreen, dtype: int64

# %%
a['Touchscreen'].value_counts().plot(kind='bar')
plt.title('Touchscreen Count',size=18)
# Out:
# Text(0.5, 1.0, 'Touchscreen Count')

# %%
#price and count Relation (count=touch and non touch)
sb.barplot(x=a['Touchscreen'],y=a['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %%
#in this code if IPS is present in screenresolution it returns 1 otherwise 0 and saved in ips column
a['Ips'] = a['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
a.head(3)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight       Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37  71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34  47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86  30636.0000            0    0

# %%
a['Ips'].value_counts().plot(kind='bar')
plt.title('IPS Display Count',size=18)
# Out:
# Text(0.5, 1.0, 'IPS Display Count')

# %%
sb.barplot(x=a['Ips'],y=a['Price'])
plt.title('price and IPS ',size=18)
# Out:
# Text(0.5, 1.0, 'price and IPS ')

# %%
#in this code screenresolution column is split 'x'
# x_res is new column that stored before 'x'
# y_res is another new col that stored after 'x' . n=1 is set to 1 ,the method will only split the string at the first occurrence

new = a['ScreenResolution'].str.split('x',n=1,expand=True)
a['X_res'] = new[0]
a['Y_res'] = new[1]
a.head(5)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
# 1.replace the str with spce
#2.find all {regular expression (one or more digits,an optional decimal point,one or more digits)}
#3 x as i/p and returns its first element of x[0]

a['X_res'] = a['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])
a.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
# datatype changing
a['X_res'] = a['X_res'].astype('int')
a['Y_res'] = a['Y_res'].astype('int')
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(1), float64(2), int32(1), int64(4), object(7)
# ...

# %%
a.corr()['Price']
# Out:
# <ipython-input-38-cff3d48e284d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
#calculating the pixel per inches
a['ppi'] = (((a['X_res']**2) + (a['Y_res']**2))**0.5/a['Inches']).astype('float')
a.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
a.corr()['Price']
# Out:
# <ipython-input-40-cff3d48e284d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()['Price']
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
#drop
a.drop(columns=['ScreenResolution','Inches','X_res','Y_res'],inplace=True)

# %%
a.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
a['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
#this lambda function is extracting the first three words from each string in the DataFrame column, and joining them back together into a new string.
a['Cpu Name'] = a['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))
a.tail()
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
#                   Memory                    Gpu       OpSys  Weight     Price  \
# 1298           128GB SSD  Intel HD Graphics 520  Windows 10    1.80  33992.64
# 1299           512GB SSD  Intel HD Graphics 520  Windows 10    1.30  79866.72
# 1300  64GB Flash Storage      Intel HD Graphics  Windows 10    1.50  12201.12
# 1301             1TB HDD     AMD Radeon R5 M330  Windows 10    2.19  40705.92
# 1302           500GB HDD      Intel HD Graphics  Windows 10    2.20  19660.32
#
# ...

# %%
#default function is block of statements that can be called when we want it
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'
a['Cpu brand'] = a['Cpu Name'].apply(fetch_processor)
a.sample(10)
# Out:
#        Company            TypeName                          Cpu  Ram  \
# 942       Acer            Notebook   Intel Core i5 7200U 2.5GHz    4
# 1206        HP            Notebook   Intel Core i5 7200U 2.5GHz    8
# 264       Dell            Notebook   Intel Core i5 7200U 2.5GHz    8
# 1213      Dell  2 in 1 Convertible   Intel Core i5 7200U 2.5GHz    8
# 937        MSI              Gaming  Intel Core i7 7700HQ 2.8GHz    8
# 857         HP  2 in 1 Convertible   Intel Core i7 7600U 2.8GHz    8
# 456       Dell            Notebook  Intel Core i7 7700HQ 2.7GHz    8
# 626   Mediacom            Notebook  Intel Atom x5-Z8350 1.44GHz    2
# 715     Lenovo            Notebook   Intel Core i5 7200U 2.5GHz    8
# 1271    Lenovo  2 in 1 Convertible   Intel Core i7 6500U 2.5GHz   16
#
#                     Memory                      Gpu       OpSys  Weight  \
# 942              500GB HDD    Intel HD Graphics 620  Windows 10   2.230
# ...

# %%
a['Cpu brand'].value_counts().plot(kind='bar')
plt.title('Cpu brand Count',size=18)
# Out:
# Text(0.5, 1.0, 'Cpu brand Count')

# %%
sb.barplot(x=a['Cpu brand'],y=a['Price'])
plt.title('Cpu brand X price',size=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
a.drop(columns=['Cpu','Cpu Name'],inplace=True)
a.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
a['Ram'].value_counts()
# Out:
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: Ram, dtype: int64

# %%
a['Ram'].value_counts().plot(kind='bar')
plt.ylabel('Count')
plt.xlabel('Ram in GB')
plt.title('Ram Count',size=18)
# Out:
# Text(0.5, 1.0, 'Ram Count')

# %%
sb.barplot(x=a['Ram'],y=a['Price'])
plt.title("Price X Ram",size=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
a['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
a['Memory'] = a['Memory'].astype(str).replace('\.0', '', regex=True) #replace  any ".0" values using regular expression with space
a["Memory"] = a["Memory"].str.replace('GB', '') #string replace
a["Memory"] = a["Memory"].str.replace('TB', '000') #   ,, with 000
new = a["Memory"].str.split("+", n = 1, expand = True)
#memory is seperated by "+" char and result is stored in new variable (n=1 [n will only occure once ,n is para])
#expand (it is a para and it set to "True" )


a["first"]= new[0] #create "first" column and store the new[0]
a["first"]=a["first"].str.strip() #removes any leading or trailing whitespace
a["second"]= new[1] #create "second" column and stored the new[1]


a["Layer1HDD"] = a["first"].apply(lambda x: 1 if "HDD" in x else 0) #if HDD is present returns 1 otherwise 0, stored in l1HDD
a["Layer1SSD"] = a["first"].apply(lambda x: 1 if "SSD" in x else 0) #if SSD is present returns 1 otherwise 0, stored in l1SSD
a["Layer1Hybrid"] = a["first"].apply(lambda x: 1 if "Hybrid" in x else 0) #if Hybrid is present returns 1 otherwise 0,stoted in l1Hyrid
a["Layer1Flash_Storage"] = a["first"].apply(lambda x: 1 if "Flash Storage" in x else 0) #if HDD is present returns 1 otherwise 0,stored in l2fla_Sto


a['first'] = a['first'].str.replace(r'\D', '') #replace '/d'(non digital charaters in regex)with space
a["second"].fillna("0", inplace = True) #missing value filled with 0


a["Layer2HDD"] = a["second"].apply(lambda x: 1 if "HDD" in x else 0) #if HDD is present returns 1 otherwise 0, stored in l2HDD
a["Layer2SSD"] = a["second"].apply(lambda x: 1 if "SSD" in x else 0) #if SSD is present returns 1 otherwise 0, stored in l2SSD
a["Layer2Hybrid"] = a["second"].apply(lambda x: 1 if "Hybrid" in x else 0) #if Hybrid is present returns 1 otherwise 0,stoted in l2Hyrid
a["Layer2Flash_Storage"] = a["second"].apply(lambda x: 1 if "Flash Storage" in x else 0) #if HDD is present returns 1 otherwise 0,stored in l2fla_Sto


a['second'] = a['second'].str.replace(r'\D', '') #replace '/d'(non digital charaters in regex)with space

a["first"] = a["first"].astype(int) #changing data type as 'int'
a["second"] = a["second"].astype(int)

a["HDD"]=(a["first"]*a["Layer1HDD"]+a["second"]*a["Layer2HDD"]) #Each line is creating a new column by multiplying the first column and the corresponding layer column by each other
a["SSD"]=(a["first"]*a["Layer1SSD"]+a["second"]*a["Layer2SSD"]) #then adding the result to the product of the second column and the corresponding layer 2 column.
a["Hybrid"]=(a["first"]*a["Layer1Hybrid"]+a["second"]*a["Layer2Hybrid"])
a["Flash_Storage"]=(a["first"]*a["Layer1Flash_Storage"]+a["second"]*a["Layer2Flash_Storage"])

a.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', #droping the unwated columns
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)
# Out:
# <ipython-input-53-6451db801b31>:20: FutureWarning: The default value of regex will change from True to False in a future version.
#   a['first'] = a['first'].str.replace(r'\D', '') #replace '/d'(non digital charaters in regex)with space
# <ipython-input-53-6451db801b31>:30: FutureWarning: The default value of regex will change from True to False in a future version.
#   a['second'] = a['second'].str.replace(r'\D', '') #replace '/d'(non digital charaters in regex)with space

# %%
a.head()
# Out:
#   Company   TypeName  Ram             Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128 SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128 Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256 SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512 SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256 SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu brand  \
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5
#
#    HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
a.drop(columns=['Memory'],inplace=True)
a.sample()
# Out:
#     Company  TypeName  Ram                    Gpu  OpSys  Weight      Price  \
# 547  Lenovo  Notebook    4  Intel HD Graphics 520  No OS    2.15  24634.008
#
#      Touchscreen  Ips         ppi      Cpu brand   HDD  SSD  Hybrid  \
# 547            0    0  141.211998  Intel Core i5  1000    0       0
#
#      Flash_Storage
# 547              0

# %%
a.corr()['Price']
# Out:
# <ipython-input-56-cff3d48e284d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()['Price']
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
a.drop(columns=['Hybrid','Flash_Storage'],inplace=True)
a.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %%
a['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
#split the first element from gpu and saved in gpu brand
a['Gpu brand'] = a['Gpu'].apply(lambda x:x.split()[0])
a.head()
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
a['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
a=a[a['Gpu brand']!= 'ARM']

# %%
sb.barplot(x=a['Gpu brand'],y=a['Price'])
plt.title("Price X Gpu Brands ",size=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
a.drop(columns=['Gpu'],inplace=True)
a.sample(5)
# Out:
# <ipython-input-63-e70a76528bd4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.drop(columns=['Gpu'],inplace=True)
#      Company            TypeName  Ram       OpSys  Weight      Price  \
# 31      Asus            Notebook    2  Windows 10    1.65   10602.72
# 321   Lenovo            Notebook    4  Windows 10    2.79   31381.92
# 63      Asus            Notebook    8  Windows 10    1.40   50136.48
# 1243    Dell  2 in 1 Convertible   16  Windows 10    2.77   95850.72
# 836     Asus              Gaming   16  Windows 10    2.90  128884.32
#
#       Touchscreen  Ips         ppi      Cpu brand   HDD  SSD Gpu brand
# 31              0    0  111.935204  AMD Processor     0    0       AMD
# 321             0    0  106.113062  Intel Core i5  1000    0    Nvidia
# ...

# %%
a['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
a['OpSys'].value_counts().plot(kind='bar')
plt.title('Operating System Count',size=18)
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
sb.barplot(x=a['OpSys'],y=a['Price'])
plt.title("Price X Opsys ",size=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'
a['os'] = a['OpSys'].apply(cat_os)
# Out:
# <ipython-input-67-d9c2797ae402>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['os'] = a['OpSys'].apply(cat_os)

# %%
a.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
a.drop(columns=['OpSys'],inplace=True)
# Out:
# <ipython-input-69-42d1627b250d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.drop(columns=['OpSys'],inplace=True)

# %%
a.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %%
sb.barplot(x=a['os'],y=a['Price'])
plt.title('Os X Price ',size=18)
plt.xticks(rotation='vertical')
plt.show()

# %%
a['Weight'].value_counts()
# Out:
# 2.20    126
# 2.10     58
# 2.00     45
# 2.40     44
# 2.30     41
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 2.26      1
# 2.34      1
# Name: Weight, Length: 171, dtype: int64

# %%
sb.displot(a['Weight'])

# %%
sb.scatterplot(x=a['Weight'],y=a['Price'],color='purple')
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
#dependency of numerical relationship
a.corr()['Price']
# Out:
# <ipython-input-75-4b9d28497eda>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   a.corr()['Price']
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sb.heatmap(a.corr())
# Out:
# <ipython-input-76-d58293563a96>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(a.corr())
# <Axes: >

# %%
a.head()
# Out:
#   Company   TypeName  Ram  Weight        Price  Touchscreen  Ips         ppi  \
# 0   Apple  Ultrabook    8    1.37   71378.6832            0    1  226.983005
# 1   Apple  Ultrabook    8    1.34   47895.5232            0    0  127.677940
# 2      HP   Notebook    8    1.86   30636.0000            0    0  141.211998
# 3   Apple  Ultrabook   16    1.83  135195.3360            0    1  220.534624
# 4   Apple  Ultrabook    8    1.37   96095.8080            0    1  226.983005
#
#        Cpu brand  HDD  SSD Gpu brand                  os
# 0  Intel Core i5    0  128     Intel                 Mac
# 1  Intel Core i5    0    0     Intel                 Mac
# 2  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  Intel Core i7    0  512       AMD                 Mac
# 4  Intel Core i5    0  256     Intel                 Mac

# %% [markdown]
# **GET_DUMMIES ENCORDING**

# %%
#get_dummies -> encoding use to convert string into numerical values
dummy=pd.get_dummies(a[['Company','TypeName','Cpu brand','Gpu brand','os']],drop_first=True)
dummy
# Out:
#       Company_Apple  Company_Asus  Company_Chuwi  Company_Dell  \
# 0                 1             0              0             0
# 1                 1             0              0             0
# 2                 0             0              0             0
# 3                 1             0              0             0
# 4                 1             0              0             0
# ...             ...           ...            ...           ...
# 1298              0             0              0             0
# 1299              0             0              0             0
# 1300              0             0              0             0
# 1301              0             0              0             0
# 1302              0             1              0             0
#
#       Company_Fujitsu  Company_Google  Company_HP  Company_Huawei  Company_LG  \
# 0                   0               0           0               0           0
# ...

# %% [markdown]
# **CONCATNATE**

# %%
#cancatnate is to combine the datas
b=pd.concat([a,dummy],axis=1)
b
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
df=b.drop(['Company','TypeName','Cpu brand','Gpu brand','os','Weight'],axis=1)
df
# Out:
#       Ram        Price  Touchscreen  Ips         ppi   HDD  SSD  \
# 0       8   71378.6832            0    1  226.983005     0  128
# 1       8   47895.5232            0    0  127.677940     0    0
# 2       8   30636.0000            0    0  141.211998     0  256
# 3      16  135195.3360            0    1  220.534624     0  512
# 4       8   96095.8080            0    1  226.983005     0  256
# ...   ...          ...          ...  ...         ...   ...  ...
# 1298    4   33992.6400            1    1  157.350512     0  128
# 1299   16   79866.7200            1    1  276.053530     0  512
# 1300    2   12201.1200            0    0  111.935204     0    0
# 1301    6   40705.9200            0    0  100.454670  1000    0
# 1302    4   19660.3200            0    0  100.454670   500    0
#
#       Company_Apple  Company_Asus  Company_Chuwi  ...  TypeName_Ultrabook  \
# 0                 1             0              0  ...                   1
# ...

# %% [markdown]
# **SPLTTING X AND Y**

# %%
#splitting data into x and y
x = df.drop(columns=['Price']).values
y = (df['Price']).values

# %%
x
# Out:
# array([[8., 0., 1., ..., 0., 0., 0.],
#        [8., 0., 0., ..., 0., 0., 0.],
#        [8., 0., 0., ..., 0., 1., 0.],
#        ...,
#        [2., 0., 0., ..., 0., 0., 1.],
#        [6., 0., 0., ..., 0., 0., 1.],
#        [4., 0., 0., ..., 0., 0., 1.]])

# %%
y
# Out:
# array([71378.6832, 47895.5232, 30636.    , ..., 12201.12  , 40705.92  ,
#        19660.32  ])

# %% [markdown]
# **TRAINING THE DATA**

# %%
#set training data and testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=1)
x_train
# Out:
# array([[ 8.,  0.,  0., ...,  0.,  0.,  1.],
#        [ 8.,  0.,  0., ...,  1.,  0.,  1.],
#        [16.,  1.,  0., ...,  0.,  0.,  1.],
#        ...,
#        [ 8.,  0.,  0., ...,  0.,  0.,  1.],
#        [16.,  0.,  0., ...,  0.,  1.,  0.],
#        [16.,  0.,  1., ...,  1.,  1.,  0.]])

# %% [markdown]
# **LINEAR REGRESSION**

# %%
#Model Creation
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
linear=r2_score(y_test,y_pred)
print('r2 score:',linear)
# Out:
# r2 score: 0.7335909178198597

# %% [markdown]
# **RANDOM FOREST REGRESSOR**

# %%
#Model Creation
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor()
model2.fit(x_train, y_train)
y_pred1=model2.predict(x_test)

# %%
from sklearn.metrics import r2_score
RandomForest=r2_score(y_test,y_pred1)
print('r2 score:',RandomForest)
# Out:
# r2 score: 0.768457440048248

# %% [markdown]
# **DECISION TREE REGRESSOR**

# %%
#Model Creation
from sklearn.tree import DecisionTreeRegressor
model3 = DecisionTreeRegressor()
model3.fit(x_train, y_train)
y_pred2=model3.predict(x_test)

# %%
from sklearn.metrics import  r2_score
decisiontree=r2_score(y_test,y_pred2)
print('r2 score:',decisiontree)
# Out:
# r2 score: 0.6257702294671192

# %% [markdown]
# **COMPARING THE r2_score OF ALL MODELS**

# %%
models=['LINEAR REGRESSION','DECISON TREE','RANDOM FOREST']
r2=[linear,decisiontree,RandomForest]
scores= pd.DataFrame({'Model':models, 'R2_score':r2})
scores
# Out:
#                Model  R2_score
# 0  LINEAR REGRESSION  0.733591
# 1       DECISON TREE  0.625770
# 2      RANDOM FOREST  0.768457

# %%
scores['R2_score']=scores['R2_score']*100
print(scores)
# Out:
#                Model   R2_score
# 0  LINEAR REGRESSION  73.359092
# 1       DECISON TREE  62.577023
# 2      RANDOM FOREST  76.845744

# %%
#sorting models based on their accuracy score
scores=scores.sort_values(by='R2_score',ascending=True)

# %% [markdown]
# **COMPARING THE SCORES USING DIFFERENT GRAPHS**

# %%
plt.figure(figsize=(5,5))
sb.lineplot(x=scores['Model'],y=scores['R2_score'],color='blue', label='r2_score')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
plt.pie(r2,labels = models)
plt.show()

# %%
plt.bar(scores['Model'], scores['R2_score'])
plt.xlabel('Model')
plt.ylabel('R2_score')
plt.title('R2_score of MODELS')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #**THANK YOU**
